# %%
# Data Cleaning, Data Pre-processing, Data Analysis

import pandas as pd
import numpy as np
amazon_data = pd.read_csv("/content/Amazon Sales data (Amazon Sales data)_Amazon Sales data.csv")      #copy the file path
amazon_data.head()                                               #Reading Dataset
# Out:
#                  Country        Item Type Order Date   Order ID  \
# 0                 Tuvalu        Baby Food  5/28/2010  669165933
# 1                Grenada           Cereal  8/22/2012  963881480
# 2                 Russia  Office Supplies   5/2/2014  341417157
# 3  Sao Tome and Principe           Fruits  6/20/2014  514321792
# 4                 Rwanda  Office Supplies   2/1/2013  115456712
#
#   Order Priority                             Region Sales Channel  Ship Date  \
# 0              H              Australia and Oceania       Offline  6/27/2010
# 1              C  Central America and the Caribbean        Online  9/15/2012
# 2              L                             Europe       Offline   5/8/2014
# 3              C                 Sub-Saharan Africa        Online   7/5/2014
# 4              L                 Sub-Saharan Africa       Offline   2/6/2013
#
#    Net Profit Margin  Total Cost  Total Profit  Total Revenue  Total Sale  \
# ...

# %%
# Total Rows and Columns

amazon_data.shape
# Out:
# (100, 16)

# %% [markdown]
# **Data Cleaning**

# %%
# All Columns

columns = list(amazon_data)

# %%
# Checking Null Values

amazon_data.isnull().sum()
# Out:
# Country              0
# Item Type            0
# Order Date           0
# Order ID             0
# Order Priority       0
# Region               0
# Sales Channel        0
# Ship Date            0
# Net Profit Margin    0
# Total Cost           0
# Total Profit         0
# Total Revenue        0
# Total Sale           0
# Unit Cost            0
# Unit Price           0
# Units Sold           0
# dtype: int64

# %%
# Calculating Total Zeros in Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost and Total Profit

(amazon_data[columns[8:14]] == 0).sum()
# Out:
# Net Profit Margin    0
# Total Cost           0
# Total Profit         0
# Total Revenue        0
# Total Sale           0
# Unit Cost            0
# dtype: int64

# %% [markdown]
# As we can see in dataset, there is NO empty values/Null values. Hence, no cleaning needed.

# %% [markdown]
# **Data Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(amazon_data['Total Cost'])
# Out:
# <ipython-input-6-d7ffcbced008>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(amazon_data['Total Cost'])
# <Axes: xlabel='Total Cost', ylabel='Density'>

# %%
sns.distplot(amazon_data['Total Profit'])
# Out:
# <ipython-input-7-81d3aa7a7cf3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(amazon_data['Total Profit'])
# <Axes: xlabel='Total Profit', ylabel='Density'>

# %%
# Converting date format
amazon_data['Order Date'] = pd.to_datetime(amazon_data['Order Date'])
amazon_data.head()
# Out:
#                  Country        Item Type Order Date   Order ID  \
# 0                 Tuvalu        Baby Food 2010-05-28  669165933
# 1                Grenada           Cereal 2012-08-22  963881480
# 2                 Russia  Office Supplies 2014-05-02  341417157
# 3  Sao Tome and Principe           Fruits 2014-06-20  514321792
# 4                 Rwanda  Office Supplies 2013-02-01  115456712
#
#   Order Priority                             Region Sales Channel  Ship Date  \
# 0              H              Australia and Oceania       Offline  6/27/2010
# 1              C  Central America and the Caribbean        Online  9/15/2012
# 2              L                             Europe       Offline   5/8/2014
# 3              C                 Sub-Saharan Africa        Online   7/5/2014
# 4              L                 Sub-Saharan Africa       Offline   2/6/2013
#
#    Net Profit Margin  Total Cost  Total Profit  Total Revenue  Total Sale  \
# ...

# %%
#Creating Year and Month columns
amazon_data['Year'] = amazon_data['Order Date'].dt.year
amazon_data['Month'] = amazon_data['Order Date'].dt.month
amazon_data.head()
# Out:
#                  Country        Item Type Order Date   Order ID  \
# 0                 Tuvalu        Baby Food 2010-05-28  669165933
# 1                Grenada           Cereal 2012-08-22  963881480
# 2                 Russia  Office Supplies 2014-05-02  341417157
# 3  Sao Tome and Principe           Fruits 2014-06-20  514321792
# 4                 Rwanda  Office Supplies 2013-02-01  115456712
#
#   Order Priority                             Region Sales Channel  Ship Date  \
# 0              H              Australia and Oceania       Offline  6/27/2010
# 1              C  Central America and the Caribbean        Online  9/15/2012
# 2              L                             Europe       Offline   5/8/2014
# 3              C                 Sub-Saharan Africa        Online   7/5/2014
# 4              L                 Sub-Saharan Africa       Offline   2/6/2013
#
#    Net Profit Margin  Total Cost  Total Profit  Total Revenue  Total Sale  \
# ...

# %%
# Creating DataFrame only with neccessary values.
amazon_data02 = amazon_data[['Units Sold','Unit Price','Unit Cost','Total Revenue','Total Cost','Total Profit']]
# Checking the correlation
plt.figure(figsize=(10,5))
sns.heatmap(amazon_data02.corr(method='pearson'), annot=True)
amazon_data02.corr(method='pearson')
# Out:
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold       1.000000   -0.070486  -0.092232       0.447784    0.374746
# Unit Price      -0.070486    1.000000   0.987270       0.752360    0.787905
# Unit Cost       -0.092232    0.987270   1.000000       0.715623    0.774895
# Total Revenue    0.447784    0.752360   0.715623       1.000000    0.983928
# Total Cost       0.374746    0.787905   0.774895       0.983928    1.000000
# Total Profit     0.564550    0.557365   0.467214       0.897327    0.804091
#
#                Total Profit
# Units Sold         0.564550
# Unit Price         0.557365
# Unit Cost          0.467214
# Total Revenue      0.897327
# Total Cost         0.804091
# Total Profit       1.000000

# %% [markdown]
# 1. Total Revenue and Total Profit have a high Pearson
# correlation coefficient, indicating a strong relationship between the two variables. Greater profit will be made if revenue is strong, and vice versa.
# 2. The correlation coefficient between units sold and unit cost is negative, which suggests that the relationship between product quantity and cost is inverse. The situation with units sold and units priced is the same. The more expensive a product is, the fewer units it is available in.
# 3. We may deduce from the heatmap above that there is a substantial correlation between Total Cost, Unit Price, Unit Cost, and Total Profit.
# 4. [Unit Price and Unit Cost] and Units Sold are entirely separate entities. The quantity of a product sold is unaffected by the price per unit, just as the cost of a unit is unaffected by the quantity of units sold.
# 5. The relationship between Total Revenue and Unit Cost, Unit Price, and Total Cost is essentially nonexistent.
